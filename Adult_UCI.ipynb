# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnamhn009/datascience/blob/master/Adult_UCI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('adult.csv')
df.head(10)
# Out:
#    age    workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90            ?   77053  ...             40   United-States  <=50K
# 1   82      Private  132870  ...             18   United-States  <=50K
# 2   66            ?  186061  ...             40   United-States  <=50K
# 3   54      Private  140359  ...             40   United-States  <=50K
# 4   41      Private  264663  ...             40   United-States  <=50K
# 5   34      Private  216864  ...             45   United-States  <=50K
# 6   38      Private  150601  ...             40   United-States  <=50K
# 7   74    State-gov   88638  ...             20   United-States   >50K
# 8   68  Federal-gov  422013  ...             40   United-States  <=50K
# 9   41      Private   70037  ...             60               ?   >50K
#
# [10 rows x 15 columns]

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education.num        16
# marital.status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital.gain        119
# capital.loss         92
# hours.per.week       94
# native.country       42
# income                2
# dtype: int64

# %%
df.describe().T
# Out:
#                   count           mean  ...       75%        max
# age             32561.0      38.581647  ...      48.0       90.0
# fnlwgt          32561.0  189778.366512  ...  237051.0  1484705.0
# education.num   32561.0      10.080679  ...      12.0       16.0
# capital.gain    32561.0    1077.648844  ...       0.0    99999.0
# capital.loss    32561.0      87.303830  ...       0.0     4356.0
# hours.per.week  32561.0      40.437456  ...      45.0       99.0
#
# [6 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       5983
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['native.country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# Greece                           29
# France                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Thailand                         18
# Laos                             18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Hungary                          13
# Honduras                         13
# Scotland                         12
# Holand-Netherlands                1
# Name: native.country, dtype: int64

# %%
df['marital.status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
df['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
df['income'].value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
sns.countplot(df['income'], palette='coolwarm', hue='relationship', data=df);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df['workclass'] = df['workclass'].replace('?', 'Private')
df['occupation'] = df['occupation'].replace('?', 'Prof.specialty')
df['native.country'] = df['native.country'].replace('?', 'United.States')

# %%
df.head(8)
# Out:
#    age  workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90    Private   77053  ...             40   United-States  <=50K
# 1   82    Private  132870  ...             18   United-States  <=50K
# 2   66    Private  186061  ...             40   United-States  <=50K
# 3   54    Private  140359  ...             40   United-States  <=50K
# 4   41    Private  264663  ...             40   United-States  <=50K
# 5   34    Private  216864  ...             45   United-States  <=50K
# 6   38    Private  150601  ...             40   United-States  <=50K
# 7   74  State-gov   88638  ...             20   United-States   >50K
#
# [8 rows x 15 columns]

# %% [markdown]
# Feature Engineering

# %%
# education Category
df.education= df.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'school')
df.education = df.education.replace('HS-grad', 'high school')
df.education = df.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'higher')
df.education = df.education.replace('Bachelors', 'undergrad')
df.education = df.education.replace('Masters', 'grad')
df.education = df.education.replace('Doctorate', 'doc')

# %%
#martial status
df['marital.status']= df['marital.status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital.status']= df['marital.status'].replace(['Never-married'], 'not-married')
df['marital.status']= df['marital.status'].replace(['Divorced', 'Separated','Widowed',
                                                   'Married-spouse-absent'], 'other')

# %%
# income
df.income = df.income.replace('<=50K', 0)
df.income = df.income.replace('>50K', 1)

# %%
df.head()
# Out:
#    age workclass  fnlwgt  ... hours.per.week  native.country income
# 0   90   Private   77053  ...             40   United-States      0
# 1   82   Private  132870  ...             18   United-States      0
# 2   66   Private  186061  ...             40   United-States      0
# 3   54   Private  140359  ...             40   United-States      0
# 4   41   Private  264663  ...             40   United-States      0
#
# [5 rows x 15 columns]

# %%
df['marital.status'].value_counts()
# Out:
# married        14999
# not-married    10683
# other           6879
# Name: marital.status, dtype: int64

# %%
df['education'].value_counts()
# Out:
# high school    10501
# higher         10316
# undergrad       5355
# school          4253
# grad            1723
# doc              413
# Name: education, dtype: int64

# %%
df.corr()
# Out:
#                      age    fnlwgt  ...  hours.per.week    income
# age             1.000000 -0.076646  ...        0.068756  0.234037
# fnlwgt         -0.076646  1.000000  ...       -0.018768 -0.009463
# education.num   0.036527 -0.043195  ...        0.148123  0.335154
# capital.gain    0.077674  0.000432  ...        0.078409  0.223329
# capital.loss    0.057775 -0.010252  ...        0.054256  0.150526
# hours.per.week  0.068756 -0.018768  ...        1.000000  0.229689
# income          0.234037 -0.009463  ...        0.229689  1.000000
#
# [7 rows x 7 columns]

# %%
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# Histogram

# %%
df.hist(figsize=(12,12), layout=(3,3), sharex=False);

# %% [markdown]
# BoxPlot

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True);

# %% [markdown]
# Plotly

# %%
px.pie(df, values='education.num', names='education', title='% of edu', 
      color_discrete_sequence = px.colors.qualitative.T10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="56f2dce9-b2c2-4e13-bd18-7f120a22485a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("56f2dce9-b2c2-4e13-bd18-7f120a22485a")) {
#                     Plotly.newPlot(
#                         '56f2dce9-b2c2-4e13-bd18-7f120a22485a',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "education=%{label}<br>education.num=%{value}", "labels": ["high school", "high school", "higher", "school", "higher", "high school", "school", "doc", "high school", "higher", "doc", "higher", "undergrad", "grad", "doc", "higher", "school", "grad", "higher", "undergrad", "undergrad", "school", "high school", "higher", "high school", "higher", "school", "school", "school", "school", "higher", "school", "higher", "undergrad", "high school", "doc", "high school", "higher", "doc", "grad", "undergrad", "grad", "higher", "grad", "high school", "undergrad", "high school", "high school", "higher", "higher", "higher", "high school", "higher", "higher", "grad", "undergrad", "higher", "higher", "undergrad", "higher", "higher", "school", "higher", "undergrad", "higher", "higher", "grad", "higher", "undergrad", "higher", "undergrad", "high school", "higher", "undergrad", "grad", "undergrad", "higher", "grad", "grad", "undergrad", "higher", "higher", "grad", "higher", "undergrad", "undergrad", "higher", "higher", "undergrad", "grad", "higher", "undergrad", "higher", "undergrad", "high school", "undergrad", "higher", "higher", "higher", "doc", "higher", "doc", "undergrad", "higher", "higher", "undergrad", "higher", "higher", "undergrad", "undergrad", "higher", "undergrad", "undergrad", "doc", "doc", "grad", "undergrad", "undergrad", "undergrad", "grad", "higher", "doc", "high school", "high school", "undergrad", "higher", "higher", "high school", "high school", "doc", "high school", "higher", "grad", "undergrad", "high school", "higher", "undergrad", "higher", "high school", "undergrad", "high school", "high school", "school", "undergrad", "high school", "school", "undergrad", "higher", "undergrad", "undergrad", "higher", "high school", "higher", "higher", "grad", "high school", "high school", "higher", "higher", "undergrad", "high school", "school", "grad", "high school", "higher", "high school", "higher", "undergrad", "higher", "higher", "undergrad", "undergrad", "high school", "undergrad", "undergrad", "high school", "undergrad", "grad", "school", "grad", "higher", "high school", "undergrad", "doc", "higher", "higher", "high school", "high school", "undergrad", "high school", "higher", "grad", "undergrad", "higher", "high school", "school", "undergrad", "school", "higher", "high school", "high school", "high school", "high school", "undergrad", "undergrad", "higher", "higher", "higher", "higher", "high school", "higher", "higher", "school", "high school", "grad", "school", "school", "higher", "school", "school", "higher", "high school", "high school", "high school", "school", "higher", "school", "undergrad", "high school", "higher", "undergrad", "higher", "high school", "higher", "high school", "higher", "higher", "undergrad", "higher", "high school", "school", "school", "high school", "higher", "grad", "high school", "higher", "school", "high school", "higher", "high school", "higher", "higher", "high school", "high school", "high school", "higher", "high school", "higher", "undergrad", "higher", "high school", "high school", "high school", "high school", "higher", "high school", "high school", "high school", "school", "high school", "school", "higher", "higher", "high school", "high school", "higher", "school", "school", "high school", "high school", "high school", "school", "school", "undergrad", "high school", "higher", "higher", "higher", "undergrad", "undergrad", "undergrad", "high school", "high school", "undergrad", "higher", "high school", "high school", "high school", "high school", "doc", "high school", "high school", "high school", "grad", "school", "undergrad", "higher", "high school", "high school", "high school", "higher", "high school", "high school", "higher", "high school", "undergrad", "higher", "high school", "high school", "higher", "high school", "undergrad", "high school", "high school", "high sc ...

# %%
sns.countplot(df['education'], hue='sex', data=df, palette='seismic');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [markdown]
# Model Building

# %%
X= df.drop(['income'], axis=1)
y = df['income']

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df1= df.copy()
df1= df1.apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    age  workclass  fnlwgt  ...  hours.per.week  native.country  income
# 0   72          3    2649  ...              39              38       0
# 1   65          3    6514  ...              17              38       0
# 2   49          3   11175  ...              39              38       0
# 3   37          3    7009  ...              39              38       0
# 4   24          3   16850  ...              39              38       0
#
# [5 rows x 15 columns]

# %%
ss= StandardScaler().fit(df1.drop('income', axis=1))

# %%
X= ss.transform(df1.drop('income', axis=1))
y= df['income']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

model = lr.fit(X_train, y_train)
prediction = model.predict(X_test)

print("Acc on training data: {:,.3f}".format(lr.score(X_train, y_train)))
print("Acc on test data: {:,.3f}".format(lr.score(X_test, y_test)))
# Out:
# Acc on training data: 0.839
# Acc on test data: 0.836

# %%
#Random Forest Classifier:
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(X_train, y_train)
prediction1 = model1.predict(X_test)

print("Acc on training data: {:,.3f}".format(rfc.score(X_train, y_train)))
print("Acc on test data: {:,.3f}".format(rfc.score(X_test, y_test)))
# Out:
# Acc on training data: 1.000
# Acc on test data: 0.855

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

print(confusion_matrix(y_test, prediction1))
# Out:
# [[6889  517]
#  [ 904 1459]]

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      7406
#            1       0.74      0.62      0.67      2363
#
#     accuracy                           0.85      9769
#    macro avg       0.81      0.77      0.79      9769
# weighted avg       0.85      0.85      0.85      9769

# %%
#Precision: tp/tp+fp

print('Precision =' , 10332/(10332+1286))
# Out:
# Precision = 0.8893096918574626

# %%
# recall= tp/tp+fn

print('Recall =', 10332/(10332+806))
# Out:
# Recall = 0.9276351230023343

# %% [markdown]
# for other class : 1 (>50K)

# %%
print('Precision = ', 2229/(2229+806))
# Out:
# Precision =  0.7344316309719934

# %%
print('Recall= ', 2229/(2229+1286))
# Out:
# Recall=  0.6341394025604552
